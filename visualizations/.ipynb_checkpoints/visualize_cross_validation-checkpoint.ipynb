# %%
# Out:
#    epoch  train_loss  train_acc  validation_loss  validation_acc  test_loss  \
# 0      1    0.317270   0.852963         0.247924        0.928082   0.153829
# 1      2    0.091730   0.967351         0.200614        0.948630   0.125040
# 2      3    0.036541   0.986948         0.250294        0.948630   0.174486
# 3      4    0.016029   0.994546         0.284464        0.962329   0.203908
# 4      5    0.011435   0.996455         0.219720        0.962329   0.210855
# 5      6    0.006444   0.998169         0.369566        0.962329   0.350835
# 6      7    0.005218   0.998636         0.367405        0.952055   0.354903
# 7      8    0.003471   0.999182         0.385752        0.952055   0.281119
#
#    test_acc
# 0  0.931507
# 1  0.957382
# 2  0.951294
# 3  0.960426
# 4  0.954338
# 5  0.945205
# 6  0.948250
# 7  0.960426

# %% [markdown]
# ## loss plot

# %%
def loss_plot(df):
    plt.plot(range(len(df['epoch'])), df['train_loss'].tolist(), 'go-')
    plt.plot(range(len(df['epoch'])), df['validation_loss'].tolist(), 'bo-')
    plt.plot(range(len(df['epoch'])), df['test_loss'].tolist(), 'ro-')
    #plt.title('model accuracy')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train','validation', 'test'],loc ='upper left')
    return plt
def acc_plot(df,plt):
    plt.plot(range(len(df['epoch'])), df['train_acc'].tolist(), 'go-')
    plt.plot(range(len(df['epoch'])), df['validation_acc'].tolist(), 'bo-')
    plt.plot(range(len(df['epoch'])), df['test_acc'].tolist(), 'ro-')
    #plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train','validation', 'test'], loc='lower right')
    return plt

# %% [markdown]
# # 1 deep 10 epochs

# %%
import pandas as pd
df = pd.read_csv('1deep_crossval_data.csv')

plt = loss_plot(df)
plt.show()

# %%
plt = acc_plot(df,plt)
plt.show()
